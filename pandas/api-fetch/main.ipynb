# %%
import requests as req

response = req.get("https://fresh-linkedin-profile-data.p.rapidapi.com/get-post-reactions?urn=7267273010393358336&type=ALL&page=1&share_urn=7315779815297421316", headers={
    'x-rapidapi-key': 'fdf5c906d2mshfe4e428ccacae37p1bea0ejsn7de2d42a2b1c',
    'x-rapidapi-host': 'fresh-linkedin-profile-data.p.rapidapi.com',
    'Content-Type': 'application/json'
})

# %%
response.json()
# Out:
# {'message': 'You are not subscribed to this API.'}

# %%
import numpy as np

arr = np.array([132, 223, 323, 423], dtype='S')

print(arr)
print(arr.dtype)
# Out:
# [b'132' b'223' b'323' b'423']
# |S3
