# %%
import pandas as pd

# %% [markdown]
# - opening a local csv file

# %%
df = pd.read_csv("./data/aug_train.csv")

# %% [markdown]
# - opening a csv file from url

# %%
import requests
from io import StringIO

# %%
url: str = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
data_request = requests.get(url=url)
data = StringIO(data_request.text)
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
pd.read_csv('./data/file.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
# Out:
#         sno  name  release_year     rating  votes  genres
# 0         0    50             5  881250949    NaN     NaN
# 1         0   172             5  881250949    NaN     NaN
# 2         0   133             1  881250949    NaN     NaN
# 3       196   242             3  881250949    NaN     NaN
# 4       186   302             3  891717742    NaN     NaN
# ...     ...   ...           ...        ...    ...     ...
# 99998   880   476             3  880175444    NaN     NaN
# 99999   716   204             5  879795543    NaN     NaN
# 100000  276  1090             1  874795795    NaN     NaN
# 100001   13   225             2  882399156    NaN     NaN
# 100002   12   203             3  879959583    NaN     NaN
#
# [100003 rows x 6 columns]

# %%
pd.read_csv("./data/aug_train.csv", index_col="enrollee_id")
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...
