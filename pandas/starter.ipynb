# %%
import pandas as pd

# %% [markdown]
# ## createing a datafram using pandas

# %%
# dataframe for the students
df = pd.DataFrame({ 
    "Name": [
        "Nishidh Singh",
        "Mark Holzarator",
        "Charris"
    ],
    "cgpa": [8, 8.3, 9],
    "iq": [123, 144, 132]
})

# %%
df
# Out:
#               Name  cgpa   iq
# 0    Nishidh Singh   8.0  123
# 1  Mark Holzarator   8.3  144
# 2          Charris   9.0  132

# %%
iq = pd.Series([123, 144, 132], name="iq")

# %%
iq
# Out:
# 0    123
# 1    144
# 2    132
# Name: iq, dtype: int64

# %%
iq.max()
# Out:
# np.int64(144)

# %%
iq.describe()
# Out:
# count      3.000000
# mean     133.000000
# std       10.535654
# min      123.000000
# 25%      127.500000
# 50%      132.000000
# 75%      138.000000
# max      144.000000
# Name: iq, dtype: float64

# %%
df.describe()
# Out:
#            cgpa          iq
# count  3.000000    3.000000
# mean   8.433333  133.000000
# std    0.513160   10.535654
# min    8.000000  123.000000
# 25%    8.150000  127.500000
# 50%    8.300000  132.000000
# 75%    8.650000  138.000000
# max    9.000000  144.000000

# %%
iq.std()
# Out:
# np.float64(10.535653752852738)

# %%
iq.quantile()
# Out:
# np.float64(132.0)
